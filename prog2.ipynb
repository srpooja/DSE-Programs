# %%
import pandas as pd
import seaborn as sns
import numpy as np
import os

# %%
os.stat('P2_mov.csv')
# Out:
# os.stat_result(st_mode=33206, st_ino=1407374884266055, st_dev=3826600504, st_nlink=1, st_uid=0, st_gid=0, st_size=5698602, st_atime=1605680702, st_mtime=1571231928, st_ctime=1605251397)

# %%
df=pd.read_csv("P2_mov.csv")

# %%
df.shape
# Out:
# (4803, 20)

# %%
df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
#  15  status                4803 non-null   object
#  16  tagline               3959 non-null   object
#  17  title                 4803 non-null   object
#  18  vote_average          4803 non-null   float64
#  19  vote_count            4803 non-null   int64
# dtypes: float64(3), int64(4), object(13)
# memory usage: 750.6+ KB

# %%
for i in df.columns:
    print(i," ",type(df[i][0]))
# Out:
# budget   <class 'numpy.int64'>
# genres   <class 'str'>
# homepage   <class 'str'>
# id   <class 'numpy.int64'>
# keywords   <class 'str'>
# original_language   <class 'str'>
# original_title   <class 'str'>
# overview   <class 'str'>
# popularity   <class 'numpy.float64'>
# production_companies   <class 'str'>
# production_countries   <class 'str'>
# release_date   <class 'str'>
# revenue   <class 'numpy.int64'>
# runtime   <class 'numpy.float64'>
# spoken_languages   <class 'str'>
# status   <class 'str'>
# tagline   <class 'str'>
# title   <class 'str'>
# vote_average   <class 'numpy.float64'>
# vote_count   <class 'numpy.int64'>

# %%
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4803, step=1)

# %% [markdown]
# # DATA Cleaning

# %% [markdown]
# ### Handling missing values

# %%
for col in df.columns:
    print(col,"  ",df[col].isna().sum())
# Out:
# budget    0
# genres    0
# homepage    3091
# id    0
# keywords    0
# original_language    0
# original_title    0
# overview    3
# popularity    0
# production_companies    0
# production_countries    0
# release_date    1
# revenue    0
# runtime    2
# spoken_languages    0
# status    0
# tagline    844
# title    0
# vote_average    0
# vote_count    0

# %%
df['runtime'].fillna(df['runtime'].mean(),inplace=True)

# %%
df['homepage'].fillna('source_unknown',inplace=True)

# %%
for c in ['homepage','runtime']:
    print(c,"  ",df[col].isna().sum())
# Out:
# homepage    0
# runtime    0

# %% [markdown]
# ## Data Integration

# %%
df1=pd.read_csv("res.csv")
# Out:
# C:\Users\srpoo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df1.head()
# Out:
#    Unnamed: 0  adult                              belongs_to_collection  \
# 0           0  False  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1           1  False                                                NaN
# 2           2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3           3  False                                                NaN
# 4           4  False  {'id': 96871, 'name': 'Father of the Bride Col...
#
#        budget                                             genres  \
# 0  30000000.0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  65000000.0  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2         0.0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  16000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4         0.0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage       id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862.0  tt0114709                en
# 1                                   NaN   8844.0  tt0113497                en
# 2                                   NaN  15602.0  tt0113228                en
# 3                                   NaN  31357.0  tt0114885                en
# 4                                   NaN  11862.0  tt0113041                en
#
#                 original_title  ... runtime  \
# 0                    Toy Story  ...    81.0
# 1                      Jumanji  ...   104.0
# 2             Grumpier Old Men  ...   101.0
# 3            Waiting to Exhale  ...   127.0
# 4  Father of the Bride Part II  ...   106.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video  vote_average  vote_count actual_profit  \
# 0                    Toy Story  False           7.7      5415.0   343554033.0
# 1                      Jumanji  False           6.9      2413.0   197797249.0
# 2             Grumpier Old Men  False           6.5        92.0           0.0
# 3            Waiting to Exhale  False           6.1        34.0    65452156.0
# 4  Father of the Bride Part II  False           5.7       173.0    76578911.0
#
#   profit_ratio
# 0    12.451801
# 1     4.043035
# 2     0.000000
# 3     5.090760
# 4     0.000000
#
# [5 rows x 27 columns]

# %%
df_new=pd.merge(df,df1,on="original_title")

# %%
df_new.head()
# Out:
#     budget_x                                           genres_x  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                      homepage_x    id_x  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language_x  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                  en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                  en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                  en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                  en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                  en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                           overview_x  popularity_x  \
# 0  In the 22nd century, a paraplegic Marine is di...    150.437577
# 1  Captain Barbossa, long believed to be dead, ha...    139.082615
# 2  A cryptic message from Bond’s past sends him o...    107.376788
# 3  Following the death of District Attorney Harve...    112.312950
# 4  John Carter is a war-weary, former military ca...     43.926995
#
#                               production_companies_x  ... runtime_y  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...     162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...     169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...     148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...     165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...     132.0
#
#                                   spoken_languages_y  status_y  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                         tagline_y  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                     title_y  video vote_average_y  \
# 0                                    Avatar  False            7.2
# 1  Pirates of the Caribbean: At World's End  False            6.9
# 2                                   Spectre  False            6.3
# 3                     The Dark Knight Rises  False            7.6
# 4                               John Carter  False            6.1
#
#   vote_count_y  actual_profit  profit_ratio
# 0      12114.0   2.550965e+09     11.763566
# 1       4627.0   6.610000e+08      3.203333
# 2       4552.0   6.356746e+08      3.594590
# 3       9263.0   8.349391e+08      4.339756
# 4       2170.0   2.413910e+07      1.092843
#
# [5 rows x 46 columns]

# %%
df=df_new

# %%
df.columns
# Out:
# Index(['budget_x', 'genres_x', 'homepage_x', 'id_x', 'keywords',
#        'original_language_x', 'original_title', 'overview_x', 'popularity_x',
#        'production_companies_x', 'production_countries_x', 'release_date_x',
#        'revenue_x', 'runtime_x', 'spoken_languages_x', 'status_x', 'tagline_x',
#        'title_x', 'vote_average_x', 'vote_count_x', 'Unnamed: 0', 'adult',
#        'belongs_to_collection', 'budget_y', 'genres_y', 'homepage_y', 'id_y',
#        'imdb_id', 'original_language_y', 'overview_y', 'popularity_y',
#        'poster_path', 'production_companies_y', 'production_countries_y',
#        'release_date_y', 'revenue_y', 'runtime_y', 'spoken_languages_y',
#        'status_y', 'tagline_y', 'title_y', 'video', 'vote_average_y',
#        'vote_count_y', 'actual_profit', 'profit_ratio'],
#       dtype='object')

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ### Normalization

# %%
print(df["runtime_y"].min(),df["runtime_y"].max())
# Out:
# 0.0 877.0

# %%
df["runtime_y"]
# Out:
# 0       162.0
# 1       169.0
# 2       148.0
# 3       165.0
# 4       132.0
#         ...
# 5235     81.0
# 5236     85.0
# 5237    120.0
# 5238     98.0
# 5239     90.0
# Name: runtime_y, Length: 5240, dtype: float64

# %%
df["runtime_y"]=((df["runtime_y"]-df["runtime_y"].min())/(df["runtime_y"].max()-df["runtime_y"].min()))*10

# %%
print(df["runtime_y"].min(),df["runtime_y"].max())
# Out:
# 0.0 10.0

# %%
print(df["budget_x"].min(),df["budget_x"].max())
# Out:
# 0 380000000

# %%
df['budget_x']=((df['budget_x']-df['budget_x'].min())/(df['budget_x'].max()-df['budget_x'].min()))*100

# %%
df['budget_x']
# Out:
# 0       62.368421
# 1       78.947368
# 2       64.473684
# 3       65.789474
# 4       68.421053
#           ...
# 5235     0.057895
# 5236     0.002368
# 5237     0.000000
# 5238     0.000000
# 5239     0.000000
# Name: budget_x, Length: 5240, dtype: float64

# %% [markdown]
# ### Adding extra column

# %%
df['profit']=df.apply(lambda row:row['revenue_x']-row['budget_x'] ,axis=1)

# %% [markdown]
# ### Changing data types

# %%
df['release_date_x'] = pd.to_datetime(df['release_date_x'], format = '%Y-%m-%d', errors='coerce')
type(df['release_date_x'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['release_date_y'] = pd.to_datetime(df['release_date_y'], format = '%Y-%m-%d', errors='coerce')
type(df['release_date_y'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# ## Data Reduction

# %%
df.columns
# Out:
# Index(['budget_x', 'genres_x', 'homepage_x', 'id_x', 'keywords',
#        'original_language_x', 'original_title', 'overview_x', 'popularity_x',
#        'production_companies_x', 'production_countries_x', 'release_date_x',
#        'revenue_x', 'runtime_x', 'spoken_languages_x', 'status_x', 'tagline_x',
#        'title_x', 'vote_average_x', 'vote_count_x', 'Unnamed: 0', 'adult',
#        'belongs_to_collection', 'budget_y', 'genres_y', 'homepage_y', 'id_y',
#        'imdb_id', 'original_language_y', 'overview_y', 'popularity_y',
#        'poster_path', 'production_companies_y', 'production_countries_y',
#        'release_date_y', 'revenue_y', 'runtime_y', 'spoken_languages_y',
#        'status_y', 'tagline_y', 'title_y', 'video', 'vote_average_y',
#        'vote_count_y', 'actual_profit', 'profit_ratio', 'profit'],
#       dtype='object')

# %%
df.shape[1]
# Out:
# 47

# %%
df.head(2)
# Out:
#     budget_x                                           genres_x  \
# 0  62.368421  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  78.947368  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                      homepage_x   id_x  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language_x  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                  en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                  en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                           overview_x  popularity_x  \
# 0  In the 22nd century, a paraplegic Marine is di...    150.437577
# 1  Captain Barbossa, long believed to be dead, ha...    139.082615
#
#                               production_companies_x  ...  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...
#
#                                   spoken_languages_y  status_y  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                         tagline_y  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                     title_y  video vote_average_y  \
# 0                                    Avatar  False            7.2
# 1  Pirates of the Caribbean: At World's End  False            6.9
#
#   vote_count_y actual_profit  profit_ratio        profit
# 0      12114.0  2.550965e+09     11.763566  2.787965e+09
# 1       4627.0  6.610000e+08      3.203333  9.609999e+08
#
# [2 rows x 47 columns]

# %%
df.corr()
# Out:
#                 budget_x      id_x  popularity_x  revenue_x  runtime_x  \
# budget_x        1.000000 -0.048746      0.505823   0.730486   0.235954
# id_x           -0.048746  1.000000      0.095342  -0.017321  -0.091962
# popularity_x    0.505823  0.095342      1.000000   0.644270   0.192562
# revenue_x       0.730486 -0.017321      0.644270   1.000000   0.228948
# runtime_x       0.235954 -0.091962      0.192562   0.228948   1.000000
# vote_average_x  0.050369 -0.132884      0.284232   0.200137   0.361488
# vote_count_x    0.592242  0.042433      0.782670   0.783269   0.243595
# Unnamed: 0      0.042138  0.658779      0.107172   0.041964  -0.073098
# budget_y        0.865506 -0.063301      0.446036   0.621478   0.211275
# id_y           -0.052737  0.852166      0.077118  -0.025621  -0.073714
# revenue_y       0.642080 -0.029752      0.591254   0.876451   0.206834
# runtime_y       0.188313 -0.094368      0.151543   0.172748   0.697825
# vote_average_y  0.032470 -0.114801      0.212568   0.143477   0.238398
# vote_count_y    0.514372  0.022486      0.714547   0.679250   0.222546
# actual_profit   0.508824 -0.016557      0.574773   0.864039   0.184349
# profit_ratio   -0.011361 -0.007803      0.001608  -0.007137  -0.013921
# profit          0.730486 -0.017321      0.644270   1.000000   0.228948
#
#                 vote_average_x  vote_count_x  Unnamed: 0  budget_y      id_y  \
# budget_x              0.050369      0.592242    0.042138  0.865506 -0.052737
# id_x                 -0.132884      0.042433    0.658779 -0.063301  0.852166
# popularity_x          0.284232      0.782670    0.107172  0.446036  0.077118
# revenue_x             0.200137      0.783269    0.041964  0.621478 -0.025621
# runtime_x             0.361488      0.243595   -0.073098  0.211275 -0.073714
# vote_average_x        1.000000      0.336574   -0.115316  0.038852 -0.113076
# vote_count_x          0.336574      1.000000    0.092454  0.517770  0.032580
# Unnamed: 0           -0.115316      0.092454    1.000000 -0.009737  0.748738
# budget_y              0.038852      0.517770   -0.009737  1.000000 -0.078663
# id_y                 -0.113076      0.032580    0.748738 -0.078663  1.000000
# revenue_y             0.179955      0.702319   -0.002797  0.733066 -0.042309
# runtime_y             0.276005      0.191699   -0.099525  0.203822 -0.072309
# vote_average_y        0.755853      0.240920   -0.209765  0.074027 -0.186556
# vote_count_y          0.310873      0.898609    0.039391  0.602091  0.009446
# actual_profit         0.204269      0.686390   -0.000410  0.577341 -0.026980
# profit_ratio          0.024994      0.000448   -0.010374 -0.010428 -0.008037
# profit                0.200137      0.783269    0.041964  0.621478 -0.025621
#
#                 revenue_y  runtime_y  vote_average_y  vote_count_y  \
# budget_x         0.642080   0.188313        0.032470      0.514372
# id_x            -0.029752  -0.094368       -0.114801      0.022486
# popularity_x     0.591254   0.151543        0.212568      0.714547
# revenue_x        0.876451   0.172748        0.143477      0.679250
# runtime_x        0.206834   0.697825        0.238398      0.222546
# vote_average_x   0.179955   0.276005        0.755853      0.310873
# vote_count_x     0.702319   0.191699        0.240920      0.898609
# Unnamed: 0      -0.002797  -0.099525       -0.209765      0.039391
# budget_y         0.733066   0.203822        0.074027      0.602091
# id_y            -0.042309  -0.072309       -0.186556      0.009446
# revenue_y        1.000000   0.191216        0.184798      0.785937
# runtime_y        0.191216   1.000000        0.226398      0.205965
# vote_average_y   0.184798   0.226398        1.000000      0.299357
# vote_count_y     0.785937   0.205965        0.299357      1.000000
# actual_profit    0.978580   0.167855        0.199437      0.761248
# profit_ratio    -0.006566  -0.010722        0.021995      0.001811
# profit           0.876451   0.172748        0.143477      0.679250
#
#                 actual_profit  profit_ratio    profit
# budget_x             0.508824     -0.011361  0.730486
# id_x                -0.016557     -0.007803 -0.017321
# popularity_x         0.574773      0.001608  0.644270
# revenue_x            0.864039     -0.007137  1.000000
# runtime_x            0.184349     -0.013921  0.228948
# vote_average_x       0.204269      0.024994  0.200137
# vote_count_x         0.686390      0.000448  0.783269
# Unnamed: 0          -0.000410     -0.010374  0.041964
# budget_y             0.577341     -0.010428  0.621478
# id_y                -0.026980     -0.008037 -0.025621
# revenue_y            0.978580     -0.006566  0.876451
# runtime_y            0.167855     -0.010722  0.172748
# vote_average_y       0.199437      0.021995  0.143477
# vote_count_y         0.761248      0.001811  0.679250
# actual_profit        1.000000     -0.004726  0.864039
# profit_ratio        -0.004726      1.000000 -0.007137
# profit               0.864039     -0.007137  1.000000

# %%
df.drop(['id_x','popularity_x','runtime_x','vote_average_x','vote_count_x','actual_profit','Unnamed: 0',
         'budget_y','id_y','revenue_y','vote_average_y','runtime_y','production_countries_x',
         'spoken_languages_x','spoken_languages_y','budget_y','original_language_y','release_date_y'],axis=1)
# Out:
#        budget_x                                           genres_x  \
# 0     62.368421  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     78.947368  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     64.473684  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     65.789474  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     68.421053  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 5235   0.057895  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 5236   0.002368  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 5237   0.000000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 5238   0.000000                                                 []
# 5239   0.000000                [{"id": 99, "name": "Documentary"}]
#
#                                              homepage_x  \
# 0                           http://www.avatarmovie.com/
# 1          http://disney.go.com/disneypictures/pirates/
# 2           http://www.sonypictures.com/movies/spectre/
# 3                    http://www.thedarkknightrises.com/
# 4                  http://movies.disney.com/john-carter
# ...                                                 ...
# 5235                                     source_unknown
# 5236                                     source_unknown
# 5237  http://www.hallmarkchannel.com/signedsealeddel...
# 5238                        http://shanghaicalling.com/
# 5239                                     source_unknown
#
#                                                keywords original_language_x  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                  en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                  en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                  en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                  en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                  en
# ...                                                 ...                 ...
# 5235  [{"id": 5616, "name": "united states\u2013mexi...                  es
# 5236                                                 []                  en
# 5237  [{"id": 248, "name": "date"}, {"id": 699, "nam...                  en
# 5238                                                 []                  en
# 5239  [{"id": 1523, "name": "obsession"}, {"id": 224...                  en
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 5235                               El Mariachi
# 5236                                 Newlyweds
# 5237                 Signed, Sealed, Delivered
# 5238                          Shanghai Calling
# 5239                         My Date with Drew
#
#                                              overview_x  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 5235  El Mariachi just wants to play his guitar and ...
# 5236  A newlywed couple's honeymoon is upended by th...
# 5237  "Signed, Sealed, Delivered" introduces a dedic...
# 5238  When ambitious New York attorney Sam is sent t...
# 5239  Ever since the second grade when he first saw ...
#
#                                  production_companies_x release_date_x  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...     2009-12-10
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...     2007-05-19
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...     2015-10-26
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...     2012-07-16
# 4           [{"name": "Walt Disney Pictures", "id": 2}]     2012-03-07
# ...                                                 ...            ...
# 5235           [{"name": "Columbia Pictures", "id": 5}]     1992-09-04
# 5236                                                 []     2011-12-26
# 5237  [{"name": "Front Street Pictures", "id": 3958}...     2013-10-13
# 5238                                                 []     2012-05-03
# 5239  [{"name": "rusty bear entertainment", "id": 87...     2005-08-05
#
#        revenue_x  ...                       poster_path  \
# 0     2787965087  ...  /kmcqlZGaSh20zpTbuoF0Cdn07dT.jpg
# 1      961000000  ...  /bXb00CkHqx7TPchTGG131sWV59y.jpg
# 2      880674609  ...  /hE24GYddaxB9MVZl1CaiI86M3kp.jpg
# 3     1084939099  ...  /dEYnvnUfXrqvqeRSqvIEtmzhoA8.jpg
# 4      284139100  ...  /4QDBNt9PmxqUH4Ab2R5xKWqzXiQ.jpg
# ...          ...  ...                               ...
# 5235     2040920  ...  /4S47gyKZI5aLiawwc45e4gnPlPx.jpg
# 5236           0  ...  /eINKU1ewT7B8sdBwyZdPYwQXQFh.jpg
# 5237           0  ...  /mdrVFUD79PpFapXVolMwAPgWppk.jpg
# 5238           0  ...  /zPpiFU2OSDCslxKArjIz1F1kMGK.jpg
# 5239           0  ...  /juhwVc2u57LqfkO9B3SK6Q0c9ff.jpg
#
#                                  production_companies_y  \
# 0     [{'name': 'Ingenious Film Partners', 'id': 289...
# 1     [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# 2     [{'name': 'Columbia Pictures', 'id': 5}, {'nam...
# 3     [{'name': 'Legendary Pictures', 'id': 923}, {'...
# 4           [{'name': 'Walt Disney Pictures', 'id': 2}]
# ...                                                 ...
# 5235           [{'name': 'Columbia Pictures', 'id': 5}]
# 5236                                                 []
# 5237  [{'name': 'Front Street Pictures', 'id': 3958}...
# 5238                                                 []
# 5239  [{'name': 'rusty bear entertainment', 'id': 87...
#
#                                  production_countries_y  status_y  \
# 0     [{'iso_3166_1': 'US', 'name': 'United States o...  Released
# 1     [{'iso_3166_1': 'US', 'name': 'United States o...  Released
# 2     [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...  Released
# 3     [{'iso_3166_1': 'US', 'name': 'United States o...  Released
# 4     [{'iso_3166_1': 'US', 'name': 'United States o...  Released
# ...                                                 ...       ...
# 5235  [{'iso_3166_1': 'MX', 'name': 'Mexico'}, {'iso...  Released
# 5236                                                 []  Released
# 5237  [{'iso_3166_1': 'US', 'name': 'United States o...  Released
# 5238  [{'iso_3166_1': 'US', 'name': 'United States o...  Released
# 5239  [{'iso_3166_1': 'US', 'name': 'United States o...  Released
#
#                                               tagline_y  \
# 0                           Enter the World of Pandora.
# 1        At the end of the world, the adventure begins.
# 2                                 A Plan No One Escapes
# 3                                       The Legend Ends
# 4                  Lost in our world, found in another.
# ...                                                 ...
# 5235  He didn't come looking for trouble, but troubl...
# 5236  A newlywed couple's honeymoon is upended by th...
# 5237                                                NaN
# 5238                           A New Yorker in Shanghai
# 5239                                                NaN
#
#                                        title_y  video vote_count_y  \
# 0                                       Avatar  False      12114.0
# 1     Pirates of the Caribbean: At World's End  False       4627.0
# 2                                      Spectre  False       4552.0
# 3                        The Dark Knight Rises  False       9263.0
# 4                                  John Carter  False       2170.0
# ...                                        ...    ...          ...
# 5235                               El Mariachi  False        243.0
# 5236                                 Newlyweds  False          6.0
# 5237                 Signed, Sealed, Delivered  False          6.0
# 5238                          Shanghai Calling  False          7.0
# 5239                         My Date with Drew  False         16.0
#
#      profit_ratio        profit
# 0       11.763566  2.787965e+09
# 1        3.203333  9.609999e+08
# 2        3.594590  8.806745e+08
# 3        4.339756  1.084939e+09
# 4        1.092843  2.841390e+08
# ...           ...           ...
# 5235     9.276909  2.040920e+06
# 5236     0.000000 -2.368421e-03
# 5237     0.000000  0.000000e+00
# 5238     0.000000  0.000000e+00
# 5239     0.000000  0.000000e+00
#
# [5240 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['budget_x', 'genres_x', 'homepage_x', 'id_x', 'keywords',
#        'original_language_x', 'original_title', 'overview_x', 'popularity_x',
#        'production_companies_x', 'production_countries_x', 'release_date_x',
#        'revenue_x', 'runtime_x', 'spoken_languages_x', 'status_x', 'tagline_x',
#        'title_x', 'vote_average_x', 'vote_count_x', 'Unnamed: 0', 'adult',
#        'belongs_to_collection', 'budget_y', 'genres_y', 'homepage_y', 'id_y',
#        'imdb_id', 'original_language_y', 'overview_y', 'popularity_y',
#        'poster_path', 'production_companies_y', 'production_countries_y',
#        'release_date_y', 'revenue_y', 'runtime_y', 'spoken_languages_y',
#        'status_y', 'tagline_y', 'title_y', 'video', 'vote_average_y',
#        'vote_count_y', 'actual_profit', 'profit_ratio', 'profit'],
#       dtype='object')

# %%
df.shape[1]
# Out:
# 47

# %% [markdown]
# ## Data Discretization

# %%
df['budget_x'].tail()
# Out:
# 5235    0.057895
# 5236    0.002368
# 5237    0.000000
# 5238    0.000000
# 5239    0.000000
# Name: budget_x, dtype: float64

# %%
df['budget_range'] = pd.cut(x=df['budget_x'], bins=[-1,10,1000,10000,100000000000], labels=['No budget','Low', 'Medium', 'High'])

# %%
df['budget_range'].tail()
# Out:
# 5235    No budget
# 5236    No budget
# 5237    No budget
# 5238    No budget
# 5239    No budget
# Name: budget_range, dtype: category
# Categories (4, object): [No budget < Low < Medium < High]

# %% [markdown]
# ## Data Visualization

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=np.array(df['vote_average_x'])
y=np.array(df['vote_count_x'])

# %%
plt.xlabel('vote_average')
plt.ylabel('vote_count')
plt.title('Votes')
plt.scatter(x,y)

# %%
x2=np.array(df['revenue_x'])[:200]
y2=np.array(df['vote_average_x'])[:200]
plt.xlabel('revenue')
plt.ylabel('vote_average')
plt.title('Line Plot')
plt.plot(x2,y2)
